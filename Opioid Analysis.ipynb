# %%
#get some packages
import numpy as np
import pandas as pd
import os
import dask.dataframe as dd
from tqdm import tqdm

# %%
#get Opioid NDCs from CDC MME dataset and set NDC field to str to maintain lead zeros.
#source: https://www.cdc.gov/drugoverdose/resources/data.html
NDC = pd.read_csv("OpioidNDCs_SAS.csv", dtype={'NDC':'str', 'NDC_Numeric':'float'})

# %%
#peek at NDC file datatypes
NDC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14549 entries, 0 to 14548
# Data columns (total 13 columns):
# NDC                      14549 non-null object
# NDC_Numeric              14549 non-null float64
# PRODNME                  14549 non-null object
# GENNME                   14549 non-null object
# Master_Form              14549 non-null object
# Class                    14549 non-null object
# Drug                     14549 non-null object
# LongShortActing          14549 non-null object
# DEAClassCode             14549 non-null int64
# Strength_Per_Unit        14545 non-null float64
# UOM                      14544 non-null object
# MME_Conversion_Factor    14324 non-null float64
# NDC_No_Lead_Zeros        14549 non-null int64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.4+ MB

# %%
#peek at the first few rows of the NDC file
NDC.head(3)
# Out:
#        NDC  NDC_Numeric        PRODNME                                GENNME  \
# 0  2035102    2035102.0  DARVOCET-N 50  Acetaminophen/propoxyphene Napsylate
# 1  2035103    2035103.0  DARVOCET-N 50  Acetaminophen/propoxyphene Napsylate
# 2  2035133    2035133.0  DARVOCET-N 50  Acetaminophen/propoxyphene Napsylate
#
#   Master_Form   Class          Drug LongShortActing  DEAClassCode  \
# 0      Tablet  Opioid  Propoxyphene              SA             4
# 1      Tablet  Opioid  Propoxyphene              SA             4
# 2      Tablet  Opioid  Propoxyphene              SA             4
#
#    Strength_Per_Unit UOM  MME_Conversion_Factor  NDC_No_Lead_Zeros
# 0               50.0  MG                   0.23            2035102
# 1               50.0  MG                   0.23            2035103
# 2               50.0  MG                   0.23            2035133

# %%
#peek at Open Payments Data
#file_path = 'open_payments_2017g.csv'
file_path = 'open_payments_2013g.csv'
df_tmp = pd.read_csv(file_path, nrows=5)
df_tmp.head()
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                    NaN
# 1   UNCHANGED  Covered Recipient Physician                    NaN
# 2   UNCHANGED  Covered Recipient Physician                    NaN
# 3   UNCHANGED  Covered Recipient Physician                    NaN
# 4   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                   NaN                     NaN                329424
# 1                   NaN                     NaN                 45253
# 2                   NaN                     NaN                 22706
# 3                   NaN                     NaN                316315
# 4                   NaN                     NaN                168313
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               Daniel                     L           McLachlan
# 1              Sandeep                     K              Bhatia
# 2                PAULA                     M            FRACASSO
# 3                DAVID                     M            HOLTZMAN
# 4                LINDA                     A              MORROW
#
#    Physician_Name_Suffix           ...             \
# 0                    NaN           ...
# 1                    NaN           ...
# 2                    NaN           ...
# 3                    NaN           ...
# 4                    NaN           ...
#
#   NDC_of_Associated_Covered_Drug_or_Biological3  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   NDC_of_Associated_Covered_Drug_or_Biological4  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   NDC_of_Associated_Covered_Drug_or_Biological5  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply1  \
# 0                          TearLab Osmolarity System
# 1                          TearLab Osmolarity System
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Name_of_Associated_Covered_Device_or_Medical_Supply2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Name_of_Associated_Covered_Device_or_Medical_Supply4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Name_of_Associated_Covered_Device_or_Medical_Supply5 Program_Year  \
# 0                                                NaN            2013
# 1                                                NaN            2013
# 2                                                NaN            2013
# 3                                                NaN            2013
# 4                                                NaN            2013
#
#   Payment_Publication_Date
# 0               01/18/2019
# 1               01/18/2019
# 2               01/18/2019
# 3               01/18/2019
# 4               01/18/2019
#
# [5 rows x 65 columns]

# %%
#peek at datatypes
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 65 columns):
# Change_Type                                                          5 non-null object
# Covered_Recipient_Type                                               5 non-null object
# Teaching_Hospital_CCN                                                0 non-null float64
# Teaching_Hospital_ID                                                 0 non-null float64
# Teaching_Hospital_Name                                               0 non-null float64
# Physician_Profile_ID                                                 5 non-null int64
# Physician_First_Name                                                 5 non-null object
# Physician_Middle_Name                                                5 non-null object
# Physician_Last_Name                                                  5 non-null object
# Physician_Name_Suffix                                                0 non-null float64
# Recipient_Primary_Business_Street_Address_Line1                      5 non-null object
# Recipient_Primary_Business_Street_Address_Line2                      4 non-null object
# Recipient_City                                                       5 non-null object
# Recipient_State                                                      5 non-null object
# Recipient_Zip_Code                                                   5 non-null int64
# Recipient_Country                                                    5 non-null object
# Recipient_Province                                                   0 non-null float64
# Recipient_Postal_Code                                                0 non-null float64
# Physician_Primary_Type                                               5 non-null object
# Physician_Specialty                                                  5 non-null object
# Physician_License_State_code1                                        5 non-null object
# Physician_License_State_code2                                        1 non-null object
# Physician_License_State_code3                                        0 non-null float64
# Physician_License_State_code4                                        0 non-null float64
# Physician_License_State_code5                                        0 non-null float64
# Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name            5 non-null object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID          5 non-null int64
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name        5 non-null object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State       5 non-null object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country     5 non-null object
# Total_Amount_of_Payment_USDollars                                    5 non-null float64
# Date_of_Payment                                                      5 non-null object
# Number_of_Payments_Included_in_Total_Amount                          5 non-null int64
# Form_of_Payment_or_Transfer_of_Value                                 5 non-null object
# Nature_of_Payment_or_Transfer_of_Value                               5 non-null object
# City_of_Travel                                                       0 non-null float64
# State_of_Travel                                                      0 non-null float64
# Country_of_Travel                                                    0 non-null float64
# Physician_Ownership_Indicator                                        5 non-null object
# Third_Party_Payment_Recipient_Indicator                              5 non-null object
# Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value    0 non-null float64
# Charity_Indicator                                                    3 non-null object
# Third_Party_Equals_Covered_Recipient_Indicator                       0 non-null float64
# Contextual_Information                                               2 non-null object
# Delay_in_Publication_Indicator                                       5 non-null object
# Record_ID                                                            5 non-null int64
# Dispute_Status_for_Publication                                       5 non-null object
# Product_Indicator                                                    5 non-null object
# Name_of_Associated_Covered_Drug_or_Biological1                       0 non-null float64
# Name_of_Associated_Covered_Drug_or_Biological2                       0 non-null float64
# Name_of_Associated_Covered_Drug_or_Biological3                       0 non-null float64
# Name_of_Associated_Covered_Drug_or_Biological4                       0 non-null float64
# Name_of_Associated_Covered_Drug_or_Biological5                       0 non-null float64
# NDC_of_Associated_Covered_Drug_or_Biological1                        0 non-null float64
# NDC_of_Associated_Covered_Drug_or_Biological2                        0 non-null float64
# NDC_of_Associated_Covered_Drug_or_Biological3                        0 non-null float64
# NDC_of_Associated_Covered_Drug_or_Biological4                        0 non-null float64
# NDC_of_Associated_Covered_Drug_or_Biological5                        0 non-null float64
# Name_of_Associated_Covered_Device_or_Medical_Supply1                 2 non-null object
# Name_of_Associated_Covered_Device_or_Medical_Supply2                 0 non-null float64
# Name_of_Associated_Covered_Device_or_Medical_Supply3                 0 non-null float64
# Name_of_Associated_Covered_Device_or_Medical_Supply4                 0 non-null float64
# Name_of_Associated_Covered_Device_or_Medical_Supply5                 0 non-null float64
# Program_Year                                                         5 non-null int64
# Payment_Publication_Date                                             5 non-null object
# dtypes: float64(29), int64(6), object(30)
# memory usage: 2.6+ KB

# %%
#set column datatypes and limit to only required columns (2013)
coltypes = {'Change_Type': 'str',
              'Covered_Recipient_Type': 'str', 
              'Physician_Profile_ID': 'str',
              'Physician_First_Name': 'str',
              'Physician_Middle_Name':'str',
              'Physician_Last_Name':'str',
              'Physician_Name_Suffix':'str',
              'Recipient_Primary_Business_Street_Address_Line1':'str',
              'Recipient_Primary_Business_Street_Address_Line2': 'str',
              'Recipient_City':'str',
              'Recipient_State': 'str',
              'Recipient_Zip_Code': 'str',
              'Recipient_Country':'str',
              'Physician_Primary_Type': 'str',
              'Physician_Specialty': 'str',
              'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID': 'str',
              'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name': 'str',
              'Total_Amount_of_Payment_USDollars': 'str',
              'Date_of_Payment': 'str',
              'Physician_Ownership_Indicator': 'str',
              'Product_Indicator': 'str',
              'Name_of_Associated_Covered_Drug_or_Biological1': 'str',
              'NDC_of_Associated_Covered_Drug_or_Biological1':'str',
              'Name_of_Associated_Covered_Drug_or_Biological2': 'str',
              'NDC_of_Associated_Covered_Drug_or_Biological2':'str',
              'Name_of_Associated_Covered_Drug_or_Biological3': 'str',
              'NDC_of_Associated_Covered_Drug_or_Biological3':'str',
              'Name_of_Associated_Covered_Drug_or_Biological4': 'str',
              'NDC_of_Associated_Covered_Drug_or_Biological4':'str'}
cols = list(coltypes.keys())

# %%
#The Open Payments Data is very big so we need to put it in chunks to bring it in for subsetting
chunksize = 1_000_000

# %%
# %%time
df_us_doc_subset = [] # list to hold the batch dataframe (2013)
df_ndc_subset = []


for df_chunk in tqdm(pd.read_csv(file_path, usecols=cols, dtype=coltypes, chunksize=chunksize)):
     
    # Neat trick from https://www.kaggle.com/btyuhas/bayesian-optimization-with-xgboost
    # Using parse_dates would be much slower!
    df_chunk['Date_of_Payment'] = df_chunk['Date_of_Payment'].str.slice(0, 16)
    df_chunk['Date_of_Payment'] = pd.to_datetime(df_chunk['Date_of_Payment'], utc=True, format='%m/%d/%Y')
    
    #clean the data up a bit and add some additional fields
    df_chunk['File_Year'] = '2013'
    df_chunk['File_Type'] = 'General'
    df_chunk['zip'] = df_chunk['Recipient_Zip_Code'].astype(str)
    df_chunk.zip = df_chunk.zip.str[:5]
    df_chunk['key'] = df_chunk['Physician_Last_Name']+'-'+df_chunk['Physician_First_Name']+'-'+df_chunk['Recipient_State']+'-'+df_chunk['zip']
    
    #do some subsetting
    filtered_us_doc = df_chunk[(df_chunk['Recipient_Country'] == 'United States') & (df_chunk['Covered_Recipient_Type']=='Covered Recipient Physician')]
    
    # Append the chunk to list and merge all
    df_us_doc_subset.append(filtered_us_doc)
    
    #Do some more data management specific to NDC
    df_chunk['NDC'] = df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].str.replace('-', '')
    df_chunk1 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('1')]
    df_chunk2 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('2')]
    df_chunk3 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('3')]
    df_chunk4 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('4')]
    df_chunk5 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('5')]
    df_chunk6 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('6')]
    df_chunk7 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('7')]
    df_chunk8 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('8')]
    df_chunk9 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('9')]
    df_chunk0 = df_chunk[df_chunk['NDC_of_Associated_Covered_Drug_or_Biological1'].astype(str).str.startswith('0')]
    frames = [df_chunk1, df_chunk2, df_chunk3, df_chunk4, df_chunk5, df_chunk6, df_chunk7, df_chunk8, df_chunk9, df_chunk0]
    df_chunk = pd.concat(frames)
    df_chunk['NDC_Numeric'] = df_chunk['NDC'].astype(float)
    
    #do some subsetting based on NDC
    filtered_ndc = pd.merge(df_chunk, NDC, on='NDC_Numeric', how='inner')
    
    # Append the chunk to list and merge all
    df_ndc_subset.append(filtered_ndc)
# Out:
# 0it [00:00, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1it [00:22, 22.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2it [00:45, 22.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3it [01:08, 22.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4it [01:34, 23.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5it [01:39, 18.27s/it]
# Wall time: 1min 40s

# %%
# Merge all dataframes into one dataframe
df_us_doc_subset_13 = pd.concat(df_us_doc_subset)

# Delete the dataframe list to release memory
del df_us_doc_subset

# See what we have loaded
df_us_doc_subset_13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4145413 entries, 0 to 4171053
# Data columns (total 33 columns):
# Change_Type                                                      object
# Covered_Recipient_Type                                           object
# Physician_Profile_ID                                             object
# Physician_First_Name                                             object
# Physician_Middle_Name                                            object
# Physician_Last_Name                                              object
# Physician_Name_Suffix                                            object
# Recipient_Primary_Business_Street_Address_Line1                  object
# Recipient_Primary_Business_Street_Address_Line2                  object
# Recipient_City                                                   object
# Recipient_State                                                  object
# Recipient_Zip_Code                                               object
# Recipient_Country                                                object
# Physician_Primary_Type                                           object
# Physician_Specialty                                              object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID      object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name    object
# Total_Amount_of_Payment_USDollars                                object
# Date_of_Payment                                                  datetime64[ns, UTC]
# Physician_Ownership_Indicator                                    object
# Product_Indicator                                                object
# Name_of_Associated_Covered_Drug_or_Biological1                   object
# Name_of_Associated_Covered_Drug_or_Biological2                   object
# Name_of_Associated_Covered_Drug_or_Biological3                   object
# Name_of_Associated_Covered_Drug_or_Biological4                   object
# NDC_of_Associated_Covered_Drug_or_Biological1                    object
# NDC_of_Associated_Covered_Drug_or_Biological2                    object
# NDC_of_Associated_Covered_Drug_or_Biological3                    object
# NDC_of_Associated_Covered_Drug_or_Biological4                    object
# File_Year                                                        object
# File_Type                                                        object
# zip                                                              object
# key                                                              object
# dtypes: datetime64[ns, UTC](1), object(32)
# memory usage: 1.1+ GB

# %%
# Merge all dataframes into one dataframe
df_ndc_subset_13 = pd.concat(df_ndc_subset)

# Delete the dataframe list to release memory
del df_ndc_subset

# See what we have loaded
df_ndc_subset_13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 0
# Data columns (total 47 columns):
# Change_Type                                                      17 non-null object
# Covered_Recipient_Type                                           17 non-null object
# Physician_Profile_ID                                             17 non-null object
# Physician_First_Name                                             17 non-null object
# Physician_Middle_Name                                            15 non-null object
# Physician_Last_Name                                              17 non-null object
# Physician_Name_Suffix                                            1 non-null object
# Recipient_Primary_Business_Street_Address_Line1                  17 non-null object
# Recipient_Primary_Business_Street_Address_Line2                  3 non-null object
# Recipient_City                                                   17 non-null object
# Recipient_State                                                  17 non-null object
# Recipient_Zip_Code                                               17 non-null object
# Recipient_Country                                                17 non-null object
# Physician_Primary_Type                                           17 non-null object
# Physician_Specialty                                              17 non-null object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID      17 non-null object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name    17 non-null object
# Total_Amount_of_Payment_USDollars                                17 non-null object
# Date_of_Payment                                                  17 non-null datetime64[ns, UTC]
# Physician_Ownership_Indicator                                    17 non-null object
# Product_Indicator                                                17 non-null object
# Name_of_Associated_Covered_Drug_or_Biological1                   17 non-null object
# Name_of_Associated_Covered_Drug_or_Biological2                   9 non-null object
# Name_of_Associated_Covered_Drug_or_Biological3                   0 non-null object
# Name_of_Associated_Covered_Drug_or_Biological4                   0 non-null object
# NDC_of_Associated_Covered_Drug_or_Biological1                    17 non-null object
# NDC_of_Associated_Covered_Drug_or_Biological2                    9 non-null object
# NDC_of_Associated_Covered_Drug_or_Biological3                    0 non-null object
# NDC_of_Associated_Covered_Drug_or_Biological4                    0 non-null object
# File_Year                                                        17 non-null object
# File_Type                                                        17 non-null object
# zip                                                              17 non-null object
# key                                                              17 non-null object
# NDC_x                                                            17 non-null object
# NDC_Numeric                                                      17 non-null float64
# NDC_y                                                            17 non-null object
# PRODNME                                                          17 non-null object
# GENNME                                                           17 non-null object
# Master_Form                                                      17 non-null object
# Class                                                            17 non-null object
# Drug                                                             17 non-null object
# LongShortActing                                                  17 non-null object
# DEAClassCode                                                     17 non-null int64
# Strength_Per_Unit                                                17 non-null float64
# UOM                                                              17 non-null object
# MME_Conversion_Factor                                            17 non-null float64
# NDC_No_Lead_Zeros                                                17 non-null int64
# dtypes: datetime64[ns, UTC](1), float64(3), int64(2), object(41)
# memory usage: 6.4+ KB

# %%
#freqency for qualitative var
df_cat_subset_13['NDC_Numeric'].value_counts()
# Out:
# 5045857810     73270
# 0169643990     70351
# 0456080060     69166
# 5045814001     65333
# 0456120130     60872
# 0169406090     59058
# 0005970135     51665
# 0001860370     51187
# 0005970075     49424
# 0001860777     46250
# 6340230430     45584
# 5914800613     43277
# 0074433902     42232
# 0003100751     37053
# 6362933571     36559
# 5551371001     34178
# 6559770118     33438
# 0002751001     32375
# 0169633990     31508
# 6678021904     31034
# 0071101268     30788
# 0456114030     30482
# 7598701003     29891
# 0051846233     29884
# 0003089321     28282
# 0003089431     27598
# 6476462530     24517
# 0003421541     24289
# 0597014030     23723
# 0078050115     23499
#                ...
# 4353818345         1
# 5254400442         1
# 0078032705         1
# 4970222248         1
# 6340270104         1
# 7648900102         1
# 7604510320         1
# 0052031510         1
# 6731339022         1
# 6872710003         1
# 1886012101         1
# 78034061           1
# 6872710002         1
# 0024079375         1
# 0003029328         1
# 0009518101         1
# 4284710330         1
# 5167252817         1
# 6879110104         1
# Betaseron          1
# 5839400704         1
# 0078038725         1
# 0045063965         1
# 1086600930         1
# 5041934210         1
# AlloDerm           1
# BladePlate         1
# Spica Table        1
# 4236754032         1
# 0078060315         1
# Name: NDC_Numeric, Length: 918, dtype: int64

# %%
#descriptive stats for quantitative var
df_cat_subset_13['Total_Amount_of_Payment_USDollars'].describe()
# Out:
# count     4145413
# unique      71907
# top        100.00
# freq        16396
# Name: Total_Amount_of_Payment_USDollars, dtype: object

# %%
#peek at Open Payments Data
file_path = 'open_payments_2017g.csv'
df_tmp = pd.read_csv(file_path, nrows=5)
df_tmp.head()

# %%
#set column datatypes and limit to only required columns (2017)
coltypes = {'Change_Type': 'str',
              'Covered_Recipient_Type': 'str', 
              'Physician_Profile_ID': 'str',
              'Physician_First_Name': 'str',
              'Physician_Middle_Name':'str',
              'Physician_Last_Name':'str',
              'Physician_Name_Suffix':'str',
              'Recipient_Primary_Business_Street_Address_Line1':'str',
              'Recipient_Primary_Business_Street_Address_Line2': 'str',
              'Recipient_City':'str',
              'Recipient_State': 'str',
              'Recipient_Zip_Code': 'str',
              'Recipient_Country':'str',
              'Physician_Primary_Type': 'str',
              'Physician_Specialty': 'str',
              'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID': 'str',
              'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name': 'str',
              'Total_Amount_of_Payment_USDollars': 'float',
              'Date_of_Payment': 'str',
              'Physician_Ownership_Indicator': 'str',
              'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1': 'str',
              'Product_Category_or_Therapeutic_Area_1': 'str',
              'Name_of_Associated_Covered_Drug_or_Biological1': 'str',
              'Associated_Drug_or_Biological_NDC_1':'str'}
cols = list(coltypes.keys())

# %%
# %%time
df_cat_subset = [] # list to hold the batch dataframe (2017)
df_ndc_merge = [] # list to hold the batch dataframe (2017)

for df_chunk in tqdm(pd.read_csv(file_path, usecols=cols, dtype=coltypes, chunksize=chunksize)):
     
    # Neat trick from https://www.kaggle.com/btyuhas/bayesian-optimization-with-xgboost
    # Using parse_dates would be much slower!
    df_chunk['Date_of_Payment'] = df_chunk['Date_of_Payment'].str.slice(0, 16)
    df_chunk['Date_of_Payment'] = pd.to_datetime(df_chunk['Date_of_Payment'], utc=True, format='%m/%d/%Y')
    
    #clean the data up a bit and add some additional fields
    df_chunk['NDC'] = df_chunk['Associated_Drug_or_Biological_NDC_1'].str.replace('-', '')
    df_chunk['NDC_Numeric'] = df_chunk['NDC'].astype(float)
    df_chunk['File_Year'] = '2017'
    df_chunk['File_Type'] = 'General'
    df_chunk['zip'] = df_chunk['Recipient_Zip_Code'].astype(str)
    df_chunk.zip = df_chunk.zip.str[:5]
    df_chunk['key'] = df_chunk['Physician_Last_Name']+'-'+df_chunk['Physician_First_Name']+'-'+df_chunk['Recipient_State']+'-'+df_chunk['zip']
    
  #do some subsetting
    filtered_cat = df_chunk[(df_chunk['Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1'] == 'Drug') & (df_chunk['Recipient_Country'] == 'United States') & (df_chunk['Covered_Recipient_Type']=='Covered Recipient Physician')]
    filtered_ndc = pd.merge(filtered_cat, NDC, on='NDC_Numeric', how='inner')
    
    # Append the chunk to list and merge all
    df_cat_subset.append(filtered_cat)
    df_ndc_merge.append(filtered_ndc)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Associated_Drug_or_Biological_NDC_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Associated_Drug_or_Biological_NDC_1'

# %%
df_cat_subset_final.info()

# %%
df_cat_subset_13.to_csv(r'C:\Users\santo\desktop\df_cat_subset_13.csv')

# %%
manufacturers = df_cat_subset_17[c(["Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name"].value_counts(), 
manufacturers.to_csv(r'C:\Users\santo\desktop\manufacturer_freq.csv')

# %%
import sys
fil=sys.argv[1]
csvfilename = open(fil, 'r').readlines()
file = 1
for j in range(len(csvfilename)):
    if j % 1000000 == 0:
        open(str(fil)+str(fil)+'.csv', 'w+').writelines(csvfilename[j:j+1000000])
        file +=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-d718adada6ab> in <module>()
#       1 import sys
#       2 fil=sys.argv[1]
# ----> 3 csvfilename = open(fil, 'r').readlines()
#       4 file = 1
#       5 for j in range(len(csvfilename)):
#
# FileNotFoundError: [Errno 2] No such file or directory: '-f'
